# %% [markdown]
# Step 1 — Load weight data from SQLite

# %%
conn = sqlite3.connect(DB_PATH)

df = pd.read_sql("""
SELECT user_id, metric_date, weight
FROM metrics
WHERE weight IS NOT NULL
ORDER BY user_id, metric_date
""", conn)

conn.close()

print("Total rows:", len(df))
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 conn = sqlite3.connect(DB_PATH)
#       3 df = pd.read_sql("""
#       4 SELECT user_id, metric_date, weight
#       5 FROM metrics
#       6 WHERE weight IS NOT NULL
#       7 ORDER BY user_id, metric_date
#       8 """, conn)
#      10 conn.close()
#
# NameError: name 'sqlite3' is not defined
